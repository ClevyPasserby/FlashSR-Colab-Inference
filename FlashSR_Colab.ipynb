# %% [markdown]
# <a href="https://colab.research.google.com/github/ClevyPasserby/FlashSR-Colab-Inference/blob/main/FlashSR_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #FlashSR Colab Inference
# One-step Versatile Audio Super-resolution via Diffusion Distillation (https://arxiv.org/abs/2501.10807)
# <br><br>
# <b>Inference with chunking and overlap !</b>
# <br><br><br><br>
# Original work by [Im, Jaekwon and Nam, Juhan ](https://github.com/jakeoneijk/FlashSR_Inference)
# <br>
# Colab by jarredou
# [![ko-fi](https://ko-fi.com/img/githubbutton_sm.svg)](https://ko-fi.com/Q5Q811R5YI)

# %%
#@title <-- Tap this if you play on Mobile { display-mode: "form" }
# %%html
<b>Press play on the music player to keep the tab alive, then start KoboldCpp below</b><br/>
<audio autoplay="" src="https://raw.githubusercontent.com/KoboldAI/KoboldAI-Client/main/colab/silence.m4a" loop controls>

# %%
#@markdown #Installation
# %%capture
# %cd /content
# !git clone https://github.com/ClevyPasserby/FlashSR_Inference
# !mkdir FlashSR_Inference/ckpts
# %cd /content/FlashSR_Inference/ckpts
# !wget https://huggingface.co/datasets/jakeoneijk/FlashSR_weights/resolve/main/sr_vocoder.pth
# !wget https://huggingface.co/datasets/jakeoneijk/FlashSR_weights/resolve/main/student_ldm.pth
# !wget https://huggingface.co/datasets/jakeoneijk/FlashSR_weights/resolve/main/vae.pth
# !pip install pydub
# %cd /content/FlashSR_Inference
# !wget https://raw.githubusercontent.com/ClevyPasserby/FlashSR-Colab-Inference/refs/heads/main/inference.py

# %%
#@markdown #gDrive connection
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/FlashSR_Inference
from pathlib import Path
import glob
#@markdown #Inference

input = '/content/drive/MyDrive/input' #@param {type:"string"}
output = '/content/drive/MyDrive/output' #@param {type:"string"}
overlap = 2 #@param {type:"slider", min:2, max:10, step:1}


# !python inference.py \
    --input "{input}" \
    --output "{output}" \
    --overlap 2
